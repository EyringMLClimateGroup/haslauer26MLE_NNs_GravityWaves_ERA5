# %%
import xarray as xr
import numpy as np

# %%
test_ua = xr.open_dataset('/p/scratch/icon-a-ml/haslauer1/_data/_ERA5/_VARS_NEW/_n32/__2022-07/ta_20220701000000_n32.grb')
test_ua
# Out:
# <xarray.Dataset> Size: 949kB
# Dimensions:        (isobaricInhPa: 37, latitude: 50, longitude: 128)
# Coordinates:
#   * isobaricInhPa  (isobaricInhPa) float64 296B 1e+03 975.0 950.0 ... 2.0 1.0
#   * latitude       (latitude) float64 400B 68.37 65.58 62.79 ... -65.58 -68.37
#   * longitude      (longitude) float64 1kB -180.0 -177.2 -174.4 ... 174.4 177.2
#     time           datetime64[ns] 8B ...
#     step           timedelta64[ns] 8B ...
#     valid_time     datetime64[ns] 8B ...
# Data variables:
#     t              (isobaricInhPa, latitude, longitude) float32 947kB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-06-09T17:02 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
test_ua_np = test_ua.t.as_numpy()[1,:,:]
test_ua_np
# Out:
# <xarray.DataArray 't' (latitude: 50, longitude: 128)> Size: 26kB
# array([[284.47266, 284.6289 , 283.33984, ..., 281.41992, 283.58203,
#         284.96875],
#        [281.01562, 284.1836 , 284.61133, ..., 282.99414, 281.01562,
#         280.22266],
#        [278.7539 , 279.4453 , 280.25   , ..., 282.14258, 280.2539 ,
#         278.75586],
#        ...,
#        [263.75586, 265.85547, 267.67383, ..., 257.86328, 259.09375,
#         261.46094],
#        [257.57617, 260.625  , 265.42773, ..., 253.61131, 253.84178,
#         255.10545],
#        [255.21678, 257.3496 , 261.71484, ..., 253.72264, 253.59178,
#         253.2246 ]], shape=(50, 128), dtype=float32)
# Coordinates:
#   * latitude       (latitude) float64 400B 68.37 65.58 62.79 ... -65.58 -68.37
#   * longitude      (longitude) float64 1kB -180.0 -177.2 -174.4 ... 174.4 177.2
#     time           datetime64[ns] 8B 2022-07-01
#     step           timedelta64[ns] 8B 00:00:00
#     isobaricInhPa  float64 8B 975.0
# ...
